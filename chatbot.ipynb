# %% [markdown]
# <a href="https://colab.research.google.com/github/cyber-mery/the-office-chatbot/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing dataset file

# %%
#import dataset file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#change the current directory => go to My Drive 
#use os (operating system) module
import os
os.chdir('/content/drive/My Drive')

# %%
#check My drive: we need the-office_lines file 
# !ls
# Out:
#  BenFadhel.doc					    Font.txt
#  Brand.svg					    Icons
#  certif.pdf					    mbf.pdf
# 'Colab Notebooks'				    mypicc.jpg
#  color-palettes.png				    rapport.pdf
# 'correction série 2 ex 3,4 et 5.pdf'		    SeanceTxTD.mp4
#  CoursBDD					   'série 3 ACM.pdf'
#  Design.png					    theOffice.csv
#  dsc_hero_720.jpg				    Transmission
#  english_test_net_100_toefl_preparation_tests.pdf   video.mp4
#  Enreg-TLC

# %%
#import re module (regular expression) and pandas
import pandas as pd
data = pd.read_csv('theOffice.csv',delimiter=',')
data.head()
# Out:
#    Unnamed: 0 Character  ... Season  Episode_Number
# 0           0   Michael  ...      1               1
# 1           1       Jim  ...      1               1
# 2           2   Michael  ...      1               1
# 3           3       Jim  ...      1               1
# 4           4   Michael  ...      1               1
#
# [5 rows x 5 columns]

# %%
#check what columns exist in my dataframe
data.columns
# Out:
# Index(['Unnamed: 0', 'Character', 'Line', 'Season', 'Episode_Number'], dtype='object')

# %%
#check if there are null values 
data.isnull().sum()
# Out:
# Unnamed: 0        0
# Character         0
# Line              0
# Season            0
# Episode_Number    0
# dtype: int64

# %%
#Extract columns that I need (Character + line)
data.describe()
# Out:
#          Unnamed: 0        Season  Episode_Number
# count  58721.000000  58721.000000    58721.000000
# mean   30796.800208      5.366768       11.607892
# std    17661.085069      2.403385        6.981443
# min        0.000000      1.000000        1.000000
# 25%    15581.000000      3.000000        5.000000
# 50%    30849.000000      5.000000       11.000000
# 75%    46061.000000      7.000000       17.000000
# max    61306.000000      9.000000       26.000000

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,7))
plt.xlabel("character")
plt.ylabel("character percentage")
plt.title("Pie chart for lines per Character",fontsize=20)
percen = data['Character'].value_counts()
plt.pie(percen, labels=percen.index, autopct='%1.1f%%', shadow=True)

plt.show()
# Michael, Dwight,Jim and Pam have the greatest percentages
